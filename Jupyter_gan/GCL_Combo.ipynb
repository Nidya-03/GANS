# %%
# !pip install gretel-client openai torch transformers pandas
# Out:
# Collecting gretel-client
#   Downloading gretel_client-0.29.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting openai
#   Downloading openai-1.88.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: torch in c:\users\2000147874\downloads\myenv\lib\site-packages (2.7.1)
# Collecting transformers
#   Using cached transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: pandas in c:\users\2000147874\downloads\myenv\lib\site-packages (2.3.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2025.6.15)
# Collecting click<9,>=8.1.3 (from gretel-client)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting inflection==0.5.1 (from gretel-client)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2==3.1.6 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (3.1.6)
# Collecting networkx==3.0 (from gretel-client)
#   Downloading networkx-3.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.3.0)
# Collecting pyarrow==19.0.1 (from gretel-client)
#   Downloading pyarrow-19.0.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting pycryptodome<4,>=3.19 (from gretel-client)
#   Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Collecting pydantic>=2 (from gretel-client)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.9.0.post0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (6.0.2)
# Requirement already satisfied: requests<3,>=2.25 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.32.4)
# Collecting rich>=13.7 (from gretel-client)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting smart-open<8.0,>=2.1.0 (from gretel-client)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting tabulate>=0.8.9 (from gretel-client)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tenacity>=8.2.2 (from gretel-client)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (4.67.1)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from jinja2==3.1.6->gretel-client) (3.0.2)
# Requirement already satisfied: colorama in c:\users\2000147874\downloads\myenv\lib\site-packages (from click<9,>=8.1.3->gretel-client) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\2000147874\downloads\myenv\lib\site-packages (from requests<3,>=2.25->gretel-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from requests<3,>=2.25->gretel-client) (3.10)
# Collecting wrapt (from smart-open<8.0,>=2.1.0->gretel-client)
#   Downloading wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from openai) (4.9.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\2000147874\downloads\myenv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\2000147874\downloads\myenv\lib\site-packages (from openai) (4.14.0)
# Requirement already satisfied: httpcore==1.* in c:\users\2000147874\downloads\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\2000147874\downloads\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->gretel-client)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2->gretel-client)
#   Using cached pydantic_core-2.33.2-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2->gretel-client)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock in c:\users\2000147874\downloads\myenv\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\2000147874\downloads\myenv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: fsspec in c:\users\2000147874\downloads\myenv\lib\site-packages (from torch) (2025.5.1)
# Requirement already satisfied: setuptools in c:\users\2000147874\downloads\myenv\lib\site-packages (from torch) (80.9.0)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers)
#   Downloading huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from transformers) (25.0)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from python-dateutil>=2.8.0->gretel-client) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.7->gretel-client)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from rich>=13.7->gretel-client) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.7->gretel-client)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Downloading gretel_client-0.29.0-py3-none-any.whl (523 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 645.7 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 645.7 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 645.7 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 645.7 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 645.7 kB/s eta 0:00:03
#    --------------- ------------------------ 0.8/2.0 MB 394.8 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 394.8 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 394.8 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 394.8 kB/s eta 0:00:04
#    -------------------- ------------------- 1.0/2.0 MB 337.8 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 337.8 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 337.8 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 337.8 kB/s eta 0:00:03
#    ------------------------- -------------- 1.3/2.0 MB 333.8 kB/s eta 0:00:03
#    ------------------------- -------------- 1.3/2.0 MB 333.8 kB/s eta 0:00:03
#    ------------------------- -------------- 1.3/2.0 MB 333.8 kB/s eta 0:00:03
#    ------------------------- -------------- 1.3/2.0 MB 333.8 kB/s eta 0:00:03
#    ------------------------------ --------- 1.6/2.0 MB 339.7 kB/s eta 0:00:02
#    ------------------------------ --------- 1.6/2
kB ? eta -:--:--
#    -------------- ------------------------- 262.1/734.3 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/734.3 kB ? eta -:--:--
#    --------------------------- ---------- 524.3/734.3 kB 541.6 kB/s eta 0:00:01
#    -------------------------------------- 734.3/734.3 kB 549.6 kB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.10.0-cp312-cp312-win_amd64.whl (206 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached transformers-4.52.4-py3-none-any.whl (10.5 MB)
# Downloading huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading wrapt-1.17.2-cp312-cp312-win_amd64.whl (38 kB)
# Installing collected packages: wrapt, typing-inspection, tenacity, tabulate, safetensors, regex, pydantic-core, pycryptodome, pyarrow, networkx, mdurl, jiter, inflection, distro, click, annotated-types, smart-open, pydantic, markdown-it-py, huggingface-hub, tokenizers, rich, openai, transformers, gretel-client
#
#    ----------------------------------------  0/25 [wrapt]
#    ----------------------------------------  0/25 [wrapt]
#    - --------------------------------------  1/25 [typing-inspection]
#    --- ------------------------------------  2/25 [tenacity]
#    --- ------------------------------------  2/25 [tenacity]
#    --- ------------------------------------  2/25 [tenacity]
#    ---- -----------------------------------  3/25 [tabulate]
#    ------ ---------------------------------  4/25 [safetensors]
#    ------ ---------------------------------  4/25 [safetensors]
#    -------- -------------------------------  5/25 [regex]
#    -------- -------------------------------  5/25 [regex]
#    -------- -------------------------------  5/25 [regex]
#    --------- ------------------------------  6/25 [pydantic-core]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ----------- ----------------------------  7/25 [pycryptodome]
#    ------------ ---------------------------  8/25 [pyarrow]
#    ------------ ---------------------------  8/25 [pyarrow]
# ...
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    ------------------------------------ --- 23/25 [transformers]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    -------------------------------------- - 24/25 [gretel-client]
#    ---------------------------------------- 25/25 [gretel-client]
#
# Successfully installed annotated-types-0.7.0 click-8.2.1 distro-1.9.0 gretel-client-0.29.0 huggingface-hub-0.33.0 inflection-0.5.1 jiter-0.10.0 markdown-it-py-3.0.0 mdurl-0.1.2 networkx-3.0 openai-1.88.0 pyarrow-19.0.1 pycryptodome-3.23.0 pydantic-2.11.7 pydantic-core-2.33.2 regex-2024.11.6 rich-14.0.0 safetensors-0.5.3 smart-open-7.1.0 tabulate-0.9.0 tenacity-9.1.2 tokenizers-0.21.1 transformers-4.52.4 typing-inspection-0.4.1 wrapt-1.17.2

# %%
import pandas as pd
from gretel_client import configure_session
from gretel_client.projects import create_or_get_unique_project
from gretel_client.helpers import poll
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
from gretel_client import configure_session

session = configure_session(api_key="grt_your_real_key", validate=True)
print("✅ API key is valid.")

# %%
# === Step 1: Configure Gretel ===
configure_session(api_key="grtuda225cfaf130a33a1af5af2d2122564630efbbac068cc1fc02cdcf83d6f6c97d", cache="yes", validate=True)
project = create_or_get_unique_project(name="gretel-lstm-gpt-synthetic")

# === Step 2: Load your CSV files (main + lookup) ===
customer_df = pd.read_csv('Customer.csv')
policy_df = pd.read_csv('Policy.csv')
claim_df = pd.read_csv('Claim.csv')
beneficiary_df = pd.read_csv('Beneficiary.csv')
coverage_df = pd.read_csv('Coverage.csv')
premium_df = pd.read_csv('Premium.csv')

policy_status_df = pd.read_csv('PolicyStatus.csv')
policy_type_df = pd.read_csv('PolicyType.csv')
payment_method_df = pd.read_csv('PaymentMethod.csv')
# Out:
# Logged in as nidyat@hexaware.com ✅

# %%
# === Step 3: Initialize GPT2 for description generation ===
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')
model.eval()

def generate_description(seed_text="Claim details: ", max_length=30):
    inputs = tokenizer.encode(seed_text, return_tensors="pt")
    outputs = model.generate(inputs, max_length=max_length, num_return_sequences=1, do_sample=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# === Step 4: Function to train Gretel model and generate synthetic data ===
def train_and_generate_synthetic(df, table_name, num_samples):
    print(f"Training Gretel model for {table_name}...")
    model = project.create_model_obj(model_config="tabular_gan.yaml", data_source=df)
    model.submit()
    poll(model)  # wait for training to complete
    print(f"Generating {num_samples} synthetic records for {table_name}...")
    records = model.get_records(num_records=num_samples)
    synth_df = pd.DataFrame([r['data'] for r in records])
    return synth_df

# === Step 5: Specify how many rows you want per table ===
num_rows = {
    'Customer': 100000,
    'Policy': 200000,
    'Claim': 350000,
    'Beneficiary': 300000,
    'Coverage': 200000,
    'Premium': 250000
}

# === Step 6: Generate synthetic data for each main table ===
synthetic_customer = train_and_generate_synthetic(customer_df, 'Customer', num_rows['Customer'])
synthetic_policy = train_and_generate_synthetic(policy_df, 'Policy', num_rows['Policy'])
synthetic_claim = train_and_generate_synthetic(claim_df, 'Claim', num_rows['Claim'])
synthetic_beneficiary = train_and_generate_synthetic(beneficiary_df, 'Beneficiary', num_rows['Beneficiary'])
synthetic_coverage = train_and_generate_synthetic(coverage_df, 'Coverage', num_rows['Coverage'])
synthetic_premium = train_and_generate_synthetic(premium_df, 'Premium', num_rows['Premium'])

# === Step 7: Manually fix foreign keys to maintain referential integrity ===

# Use lookup tables (sampled with replacement) for FK columns in Policy
synthetic_policy['status_id'] = policy_status_df['status_id'].sample(n=len(synthetic_policy), replace=True).values
synthetic_policy['type_id'] = policy_type_df['type_id'].sample(n=len(synthetic_policy), replace=True).values
synthetic_policy['customer_id'] = synthetic_customer['customer_id'].sample(n=len(synthetic_policy), replace=True).values

# Fix FK columns for other main tables referencing Policy and PaymentMethod
synthetic_claim['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_claim), replace=True).values

synthetic_beneficiary['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_beneficiary), replace=True).values

synthetic_coverage['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_coverage), replace=True).values
synthetic_coverage['coverage_type_id'] = policy_type_df['type_id'].sample(n=len(synthetic_coverage), replace=True).values  # assuming coverage_type_id linked to PolicyType

synthetic_premium['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_premium), replace=True).values
synthetic_premium['payment_method_id'] = payment_method_df['method_id'].sample(n=len(synthetic_premium), replace=True).values

# === Step 8: Generate synthetic 'description' field for Claim using GPT2 ===
synthetic_claim['description'] = synthetic_claim['description'].apply(lambda x: generate_description("Claim details: "))

# === Step 9: Save all synthetic datasets ===
synthetic_customer.to_csv('synthetic_Customer.csv', index=False)
synthetic_policy.to_csv('synthetic_Policy.csv', index=False)
synthetic_claim.to_csv('synthetic_Claim.csv', index=False)
synthetic_beneficiary.to_csv('synthetic_Beneficiary.csv', index=False)
synthetic_coverage.to_csv('synthetic_Coverage.csv', index=False)
synthetic_premium.to_csv('synthetic_Premium.csv', index=False)

print("Synthetic data generation complete and saved to CSVs.")
# Out:
# Training Gretel model for Customer...
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[35], line 33
#      23 num_rows = {
#      24     'Customer': 100000,
#      25     'Policy': 200000,
#    (...)     29     'Premium': 250000
#      30 }
#      32 # === Step 6: Generate synthetic data for each main table ===
# ---> 33 synthetic_customer = train_and_generate_synthetic(customer_df, 'Customer', num_rows['Customer'])
#      34 synthetic_policy = train_and_generate_synthetic(policy_df, 'Policy', num_rows['Policy'])
#      35 synthetic_claim = train_and_generate_synthetic(claim_df, 'Claim', num_rows['Claim'])
#
# Cell In[35], line 15, in train_and_generate_synthetic(df, table_name, num_samples)
#      13 print(f"Training Gretel model for {table_name}...")
#      14 model = project.create_model_obj(model_config="tabular_gan.yaml", data_source=df)
# ---> 15 model.submit()
#      16 poll(model)  # wait for training to complete
#      17 print(f"Generating {num_samples} synthetic records for {table_name}...")
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:136, in Job.submit(self, runner_mode, dry_run)
#     131     raise ValueError(
#     132         f"Specified runner mode '{runner_mode.value}' is different from project runner mode '{self.project.runner_mode.value}'"
#     133     )
#     135 if runner_mode == RunnerMode.CLOUD:
# --> 136     return self.submit_cloud(dry_run)
#     137 elif runner_mode == RunnerMode.HYBRID:
#     138     return self.submit_hybrid(dry_run)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:168, in Job.submit_cloud(self, dry_run)
#     162 def submit_cloud(self, dry_run: bool = False) -> Job:
#     163     """Submit this Job to the Gretel Cloud API be scheduled for running in Gretel Cloud.
#     164
#     165     Returns:
#     166         The response from the Gretel API.
#     167     """
# --> 168     return self._submit_remote(
#     169         runner_mode=RunnerMode.CLOUD,
#     170         artifacts_handler=self.project.cloud_artifacts_handler,
#     171         dry_run=dry_run,
#     172     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:202, in Job._submit_remote(self, runner_mode, artifacts_handler, dry_run)
#     199 if not self.ref_data.is_empty:
#     200     self.upload_ref_data(_artifacts_handler=artifacts_handler)
# --> 202 return self._submit(runner_mode=runner_mode, dry_run=dry_run)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:216, in Model._submit(self, runner_mode, dry_run)
#     209     resp = self._projects_api.create_model(
#     210         project_id=self.project.project_guid,
#     211         body=body,
#     212         dry_run=YES if dry_run else NO,
#     213         runner_mode=runner_mode.api_value,
#     214     )
#     215 except ApiException as ex:
# --> 216     self._handle_submit_error(ex)
#     218 self._data: dict = resp[f.DATA]
#     219 self.worker_key = resp[f.WORKER_KEY]
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:621, in Job._handle_submit_error(self, apix)
#     619     exc.body = apix.body
#     620     raise exc from apix
# --> 621 raise apix
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:209, in Model._submit(self, runner_mode, dry_run)
#     203     body = {
#     204         "config": body,
#     205         "provenance": provenance,
#     206     }
#     208 try:
# --> 209     resp = self._projects_api.create_model(
#     210         project_id=self.project.project_guid,
#     211         body=body,
#     212         dry_run=YES if dry_run else NO,
#     213         runner_mode=runner_mode.api_value,
#     214     )
#     215 except ApiException as ex:
#     216     self._handle_submit_error(ex)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:840, in Endpoint.__call__(self, *args, **kwargs)
#     829 def __call__(self, *args, **kwargs):
#     830     """This method is invoked when endpoints are called
#     831     Example:
#     832
#    (...)    838
#     839     """
# --> 840     return self.callable(self, *args, **kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api\projects_api.py:317, in ProjectsApi.__init__.<locals>.__create_model(self, project_id, body, **kwargs)
#     315 kwargs["project_id"] = project_id
#     316 kwargs["body"] = body
# --> 317 return self.call_with_http_info(**kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:912, in Endpoint.call_with_http_info(self, **kwargs)
#     907     header_list = self.api_client.select_header_content_type(
#     908         content_type_headers_list
#     909     )
#     910     params["header"]["Content-Type"] = header_list
# --> 912 return self.api_client.call_api(
#     913     self.settings["endpoint_path"],
#     914     self.settings["http_method"],
#     915     params["path"],
#     916     params["query"],
#     917     params["header"],
#     918     body=params["body"],
#     919     post_params=params["form"],
#     920     files=params["file"],
#     921     response_type=self.settings["response_type"],
#     922     auth_settings=self.settings["auth"],
#     923     async_req=kwargs["async_req"],
#     924     _check_type=kwargs["_check_return_type"],
#     925     _return_http_data_only=kwargs["_return_http_data_only"],
#     926     _preload_content=kwargs["_preload_content"],
#     927     _request_timeout=kwargs["_request_timeout"],
#     928     _host=_host,
#     929     collection_formats=params["collection_format"],
#     930 )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:424, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     370 """Makes the HTTP request (synchronous) and returns deserialized data.
#     371
#     372 To make an async_req request, set the async_req parameter.
#    (...)    421     then the method will return the response directly.
#     422 """
#     423 if not async_req:
# --> 424     return self.__call_api(
#     425         resource_path,
#     426         method,
#     427         path_params,
#     428         query_params,
#     429         header_params,
#     430         body,
#     431         post_params,
#     432         files,
#     433         response_type,
#     434         auth_settings,
#     435         _return_http_data_only,
#     436         collection_formats,
#     437         _preload_content,
#     438         _request_timeout,
#     439         _host,
#     440         _check_type,
#     441     )
#     443 return self.pool.apply_async(
#     444     self.__call_api,
#     445     (
#    (...)    462     ),
#     463 )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:211, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     209 except ApiException as e:
#     210     e.body = e.body.decode("utf-8")
# --> 211     raise e
#     213 self.last_response = response_data
#     215 return_data = response_data
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:199, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     195     url = _host + resource_path
#     197 try:
#     198     # perform request and return response
# --> 199     response_data = self.request(
#     200         method,
#     201         url,
#     202         query_params=query_params,
#     203         headers=header_params,
#     204         post_params=post_params,
#     205         body=body,
#     206         _preload_content=_preload_content,
#     207         _request_timeout=_request_timeout,
#     208     )
#     209 except ApiException as e:
#     210     e.body = e.body.decode("utf-8")
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:504, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     494     return self.rest_client.OPTIONS(
#     495         url,
#     496         query_params=query_params,
#    (...)    501         body=body,
#     502     )
#     503 elif method == "POST":
# --> 504     return self.rest_client.POST(
#     505         url,
#     506         query_params=query_params,
#     507         headers=headers,
#     508         post_params=post_params,
#     509         _preload_content=_preload_content,
#     510         _request_timeout=_request_timeout,
#     511         body=body,
#     512     )
#     513 elif method == "PUT":
#     514     return self.rest_client.PUT(
#     515         url,
#     516         query_params=query_params,
#    (...)    521         body=body,
#     522     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\rest.py:335, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     325 def POST(
#     326     self,
#     327     url,
#    (...)    333     _request_timeout=None,
#     334 ):
# --> 335     return self.request(
#     336         "POST",
#     337         url,
#     338         headers=headers,
#     339         query_params=query_params,
#     340         post_params=post_params,
#     341         _preload_content=_preload_content,
#     342         _request_timeout=_request_timeout,
#     343         body=body,
#     344     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\rest.py:247, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     244     if 500 <= r.status <= 599:
#     245         raise ServiceException(http_resp=r)
# --> 247     raise ApiException(http_resp=r)
#     249 return r
#
# ApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'date': 'Thu, 19 Jun 2025 05:13:42 GMT', 'server': 'uvicorn', 'content-type': 'application/json', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-length': '204'})
# HTTP response body: {"message": "Invalid Gretel Configuration", "context": {"validation_errors": [{"loc": ["models"], "msg": "Unknown model in the config 'synthetics/tabular-gan'", "type": "value_error"}]}, "error_id": null}

# %%
from gretel_client import configure_session
from gretel_client.projects import create_or_get_unique_project
from gretel_client.helpers import poll
import pandas as pd

# Paste your actual Gretel API key here
configure_session(
    api_key="grtuda225cfaf130a33a1af5af2d2122564630efbbac068cc1fc02cdcf83d6f6c97d", 
    cache="yes", 
    validate=True
)

# Create or get your project
project = create_or_get_unique_project(name="gretel-lstm-gpt-synthetic")
# Out:
# Logged in as nidyat@hexaware.com ✅

# %%
# === Step 2: Load all data ===
customer_df = pd.read_csv("Customer.csv")
policy_df = pd.read_csv("Policy.csv")
claim_df = pd.read_csv("Claim.csv")
beneficiary_df = pd.read_csv("Beneficiary.csv")
coverage_df = pd.read_csv("Coverage.csv")
premium_df = pd.read_csv("Premium.csv")

# Lookup tables
policy_status_df = pd.read_csv("PolicyStatus.csv")
policy_type_df = pd.read_csv("PolicyType.csv")
coverage_type_df = pd.read_csv("CoverageType.csv")
payment_method_df = pd.read_csv("PaymentMethod.csv")

# %%
payment_method_df = payment_method_df.rename(columns={"method_id": "payment_method_id"})

# %%
# === Step 3: Merge lookup tables for training (temporary) ===
policy_df = policy_df.merge(policy_status_df, on="status_id", how="left")
policy_df = policy_df.merge(policy_type_df, on="type_id", how="left")
coverage_df = coverage_df.merge(coverage_type_df, on="coverage_type_id", how="left")
premium_df = premium_df.merge(payment_method_df, on="payment_method_id", how="left")

# %%
pip install --upgrade gretel-client
# Out:
# Requirement already satisfied: gretel-client in c:\users\2000147874\downloads\myenv\lib\site-packages (0.29.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2025.6.15)
# Requirement already satisfied: click<9,>=8.1.3 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (8.2.1)
# Requirement already satisfied: inflection==0.5.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (0.5.1)
# Requirement already satisfied: jinja2==3.1.6 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (3.1.6)
# Requirement already satisfied: networkx==3.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (3.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.3.0)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.3.0)
# Requirement already satisfied: pyarrow==19.0.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (19.0.1)
# Requirement already satisfied: pycryptodome<4,>=3.19 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (3.23.0)
# Requirement already satisfied: pydantic>=2 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.11.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.9.0.post0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (6.0.2)
# Requirement already satisfied: requests<3,>=2.25 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.32.4)
# Requirement already satisfied: rich>=13.7 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (14.0.0)
# Requirement already satisfied: smart-open<8.0,>=2.1.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (7.1.0)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (0.9.0)
# Requirement already satisfied: tenacity>=8.2.2 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (9.1.2)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (4.67.1)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from gretel-client) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from jinja2==3.1.6->gretel-client) (3.0.2)
# Requirement already satisfied: colorama in c:\users\2000147874\downloads\myenv\lib\site-packages (from click<9,>=8.1.3->gretel-client) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\2000147874\downloads\myenv\lib\site-packages (from requests<3,>=2.25->gretel-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from requests<3,>=2.25->gretel-client) (3.10)
# Requirement already satisfied: wrapt in c:\users\2000147874\downloads\myenv\lib\site-packages (from smart-open<8.0,>=2.1.0->gretel-client) (1.17.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pandas>=1.1.0->gretel-client) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pandas>=1.1.0->gretel-client) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pydantic>=2->gretel-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pydantic>=2->gretel-client) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pydantic>=2->gretel-client) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from pydantic>=2->gretel-client) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\2000147874\downloads\myenv\lib\site-packages (from python-dateutil>=2.8.0->gretel-client) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from rich>=13.7->gretel-client) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\2000147874\downloads\myenv\lib\site-packages (from rich>=13.7->gretel-client) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\2000147874\downloads\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7->gretel-client) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

actgan_config = {
    "schema_version": "1.0",
    "name": "tabular-synthesizer",
    "models": [
        {
            "gretel/synthetics": {
                "data_source": "data_source",
                "params": {
                    "model_type": "actgan",  # latest supported model
                    "epochs": 100,
                    "batch_size": 500,
                    "gen_temp": 1.0
                }
            }
        }
    ]
}

with open("actgan_config.yaml", "w") as f:
    yaml.dump(actgan_config, f)

# %%
# === Step 4: Train and Generate Synthetic Data ===

def train_and_generate(df, table_name, num_records):
    print(f"Training model for {table_name}...")
    model = project.create_model_obj(model_config="tabular/actgan", data_source=df)
    model.submit()
    poll(model)
    
    # Download the synthetic records
    records_url = model.get_artifact_link("synthetic_data")
    df_synth = pd.read_csv(records_url)
    df_synth["__source_table__"] = table_name
    return df_synth.head(num_records)

# %%
# === Step 5: Run generation ===
synth_customer = train_and_generate(customer_df, "Customer", 100000)
synth_policy = train_and_generate(policy_df, "Policy", 200000)
synth_claim = train_and_generate(claim_df, "Claim", 300000)
synth_beneficiary = train_and_generate(beneficiary_df, "Beneficiary", 250000)
synth_coverage = train_and_generate(coverage_df, "Coverage", 300000)
synth_premium = train_and_generate(premium_df, "Premium", 250000)

# === Step 6: Save the outputs ===
synth_customer.to_csv("synthetic_customer.csv", index=False)
synth_policy.to_csv("synthetic_policy.csv", index=False)
synth_claim.to_csv("synthetic_claim.csv", index=False)
synth_beneficiary.to_csv("synthetic_beneficiary.csv", index=False)
synth_coverage.to_csv("synthetic_coverage.csv", index=False)
synth_premium.to_csv("synthetic_premium.csv", index=False)

print("✅ All synthetic datasets generated and saved.")
# Out:
# Training model for Customer...
# ---------------------------------------------------------------------------
# ModelConfigError                          Traceback (most recent call last)
# Cell In[7], line 2
#       1 # === Step 5: Run generation ===
# ----> 2 synth_customer = train_and_generate(customer_df, "Customer", 100000)
#       3 synth_policy = train_and_generate(policy_df, "Policy", 200000)
#       4 synth_claim = train_and_generate(claim_df, "Claim", 300000)
#
# Cell In[6], line 5, in train_and_generate(df, table_name, num_records)
#       3 def train_and_generate(df, table_name, num_records):
#       4     print(f"Training model for {table_name}...")
# ----> 5     model = project.create_model_obj(model_config="tabular/actgan", data_source=df)
#       6     model.submit()
#       7     poll(model)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\projects.py:62, in check_not_deleted.<locals>.wrap(self, *args, **kwargs)
#      58 if self._deleted:
#      59     raise GretelProjectError(
#      60         "Cannot call method. The project has been marked for deletion."
#      61     )
# ---> 62 return func(self, *args, **kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\projects.py:282, in Project.create_model_obj(self, model_config, data_source, ref_data)
#     261 @check_not_deleted
#     262 def create_model_obj(
#     263     self,
#    (...)    266     ref_data: Optional[RefDataTypes] = None,
#     267 ) -> Model:
#     268     """Creates a new model object. This will not submit the model
#     269     to Gretel's cloud API. Please refer to the ``Model`` docs for
#     270     more information detailing how to submit the model.
#    (...)    280             to upload for the job.
#     281     """
# --> 282     _model = Model(model_config=model_config, project=self)
#     283     if (
#     284         not isinstance(data_source, _DataFrameT)
#     285         and data_source
#     286         and not isinstance(data_source, str)
#     287     ):
#     288         raise ValueError("data_source must be a str or dataframe")
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:168, in Model.__init__(self, project, model_config, model_id)
#     166 self._local_model_config_path = None
#     167 if model_config:
# --> 168     self._local_model_config = read_model_config(model_config)
#     169     if isinstance(model_config, (str, Path)):
#     170         self._local_model_config_path = Path(model_config)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:141, in read_model_config(model_config, base_url)
#     138         pass
#     140 if not config:
# --> 141     raise ModelConfigError(f"Could not find model config '{model_config}'")
#     143 return config
#
# ModelConfigError: Could not find model config 'tabular/actgan'

# %%
from gretel_client.projects.models import list_model_configs

print(list_model_configs())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from gretel_client.projects.models import list_model_configs
#       3 print(list_model_configs())
#
# ImportError: cannot import name 'list_model_configs' from 'gretel_client.projects.models' (C:\Users\2000147874\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py)

# %%
import pandas as pd
from gretel_client import configure_session
from gretel_client.projects import create_or_get_unique_project
from gretel_client.helpers import poll
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# === Step 1: Configure Gretel ===
configure_session(api_key="grtuda225cfaf130a33a1af5af2d2122564630efbbac068cc1fc02cdcf83d6f6c97d", cache="yes", validate=True)
project = create_or_get_unique_project(name="gretel-tabular-gan-synthetic")
# Out:
# Logged in as nidyat@hexaware.com ✅

# %%
yaml_config = """
schema_version: "1.0"
models:
  - tabular_gan:
      data_source: __tmp__
      params:
        epochs: auto
        generator_dim: [1024, 1024]
        discriminator_dim: [1024, 1024]
        generator_lr: 0.0001
        discriminator_lr: 0.00033
        batch_size: auto
        auto_transform_datetimes: False
"""

with open("tabular_gan.yaml", "w") as file:
    file.write(yaml_config.strip())

# %%
model = project.create_model_obj(model_config=model_config, data_source=table_df)
model.submit()
model.wait_for_completion()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model = project.create_model_obj(model_config=model_config, data_source=table_df)
#       2 model.submit()
#       3 model.wait_for_completion()
#
# NameError: name 'table_df' is not defined

# %%
# === Step 2: Load your CSV files ===
customer_df = pd.read_csv('Customer.csv')
policy_df = pd.read_csv('Policy.csv')
claim_df = pd.read_csv('Claim.csv')
beneficiary_df = pd.read_csv('Beneficiary.csv')
coverage_df = pd.read_csv('Coverage.csv')
premium_df = pd.read_csv('Premium.csv')

policy_status_df = pd.read_csv('PolicyStatus.csv')
policy_type_df = pd.read_csv('PolicyType.csv')
payment_method_df = pd.read_csv('PaymentMethod.csv')

# === Step 3: Initialize GPT2 for descriptions ===
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')
model.eval()

def generate_description(seed_text="Claim details: ", max_length=30):
    inputs = tokenizer.encode(seed_text, return_tensors="pt")
    outputs = model.generate(inputs, max_length=max_length, num_return_sequences=1, do_sample=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# === Step 4: Function to train Gretel Tabular GAN and generate synthetic data ===
def train_and_generate_tabular_gan(df, table_name, num_samples):
    print(f"Training Gretel Tabular GAN model for {table_name}...")
    
    # Create model specifying the Tabular GAN model config (from Gretel docs)
    model = project.create_model_obj(
        model_config="tabular_gan.yaml",
        data_source=df
    )
    
    model.submit()
    poll(model)  # wait until training completes
    
    print(f"Generating {num_samples} synthetic records for {table_name}...")
    records = model.get_records(num_records=num_samples)
    synth_df = pd.DataFrame([r['data'] for r in records])
    return synth_df

# === Step 5: Specify how many synthetic rows per main table ===
num_rows = {
    'Customer': 100000,
    'Policy': 200000,
    'Claim': 250000,
    'Beneficiary': 300000,
    'Coverage': 250000,
    'Premium': 200000
}

# === Step 6: Generate synthetic datasets for main tables ===
synthetic_customer = train_and_generate_tabular_gan(customer_df, 'Customer', num_rows['Customer'])
synthetic_policy = train_and_generate_tabular_gan(policy_df, 'Policy', num_rows['Policy'])
synthetic_claim = train_and_generate_tabular_gan(claim_df, 'Claim', num_rows['Claim'])
synthetic_beneficiary = train_and_generate_tabular_gan(beneficiary_df, 'Beneficiary', num_rows['Beneficiary'])
synthetic_coverage = train_and_generate_tabular_gan(coverage_df, 'Coverage', num_rows['Coverage'])
synthetic_premium = train_and_generate_tabular_gan(premium_df, 'Premium', num_rows['Premium'])

# === Step 7: Manually fix foreign keys to maintain referential integrity ===
synthetic_policy['status_id'] = policy_status_df['status_id'].sample(n=len(synthetic_policy), replace=True).values
synthetic_policy['type_id'] = policy_type_df['type_id'].sample(n=len(synthetic_policy), replace=True).values
synthetic_policy['customer_id'] = synthetic_customer['customer_id'].sample(n=len(synthetic_policy), replace=True).values

synthetic_claim['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_claim), replace=True).values
synthetic_beneficiary['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_beneficiary), replace=True).values
synthetic_coverage['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_coverage), replace=True).values
synthetic_coverage['coverage_type_id'] = policy_type_df['type_id'].sample(n=len(synthetic_coverage), replace=True).values

synthetic_premium['policy_id'] = synthetic_policy['policy_id'].sample(n=len(synthetic_premium), replace=True).values
synthetic_premium['payment_method_id'] = payment_method_df['method_id'].sample(n=len(synthetic_premium), replace=True).values

# === Step 8: Generate GPT-based description for Claims ===
synthetic_claim['description'] = synthetic_claim['description'].apply(lambda x: generate_description("Claim details: "))

# === Step 9: Save synthetic data to CSV ===
synthetic_customer.to_csv('synthetic_Customer.csv', index=False)
synthetic_policy.to_csv('synthetic_Policy.csv', index=False)
synthetic_claim.to_csv('synthetic_Claim.csv', index=False)
synthetic_beneficiary.to_csv('synthetic_Beneficiary.csv', index=False)
synthetic_coverage.to_csv('synthetic_Coverage.csv', index=False)
synthetic_premium.to_csv('synthetic_Premium.csv', index=False)

print("Tabular GAN synthetic data generation complete and saved to CSV files.")
# Out:
# Training Gretel Tabular GAN model for Customer...
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[28], line 52
#      42 num_rows = {
#      43     'Customer': 100000,
#      44     'Policy': 200000,
#    (...)     48     'Premium': 200000
#      49 }
#      51 # === Step 6: Generate synthetic datasets for main tables ===
# ---> 52 synthetic_customer = train_and_generate_tabular_gan(customer_df, 'Customer', num_rows['Customer'])
#      53 synthetic_policy = train_and_generate_tabular_gan(policy_df, 'Policy', num_rows['Policy'])
#      54 synthetic_claim = train_and_generate_tabular_gan(claim_df, 'Claim', num_rows['Claim'])
#
# Cell In[28], line 33, in train_and_generate_tabular_gan(df, table_name, num_samples)
#      27 # Create model specifying the Tabular GAN model config (from Gretel docs)
#      28 model = project.create_model_obj(
#      29     model_config="tabular_gan.yaml",
#      30     data_source=df
#      31 )
# ---> 33 model.submit()
#      34 poll(model)  # wait until training completes
#      36 print(f"Generating {num_samples} synthetic records for {table_name}...")
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:136, in Job.submit(self, runner_mode, dry_run)
#     131     raise ValueError(
#     132         f"Specified runner mode '{runner_mode.value}' is different from project runner mode '{self.project.runner_mode.value}'"
#     133     )
#     135 if runner_mode == RunnerMode.CLOUD:
# --> 136     return self.submit_cloud(dry_run)
#     137 elif runner_mode == RunnerMode.HYBRID:
#     138     return self.submit_hybrid(dry_run)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:168, in Job.submit_cloud(self, dry_run)
#     162 def submit_cloud(self, dry_run: bool = False) -> Job:
#     163     """Submit this Job to the Gretel Cloud API be scheduled for running in Gretel Cloud.
#     164
#     165     Returns:
#     166         The response from the Gretel API.
#     167     """
# --> 168     return self._submit_remote(
#     169         runner_mode=RunnerMode.CLOUD,
#     170         artifacts_handler=self.project.cloud_artifacts_handler,
#     171         dry_run=dry_run,
#     172     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:202, in Job._submit_remote(self, runner_mode, artifacts_handler, dry_run)
#     199 if not self.ref_data.is_empty:
#     200     self.upload_ref_data(_artifacts_handler=artifacts_handler)
# --> 202 return self._submit(runner_mode=runner_mode, dry_run=dry_run)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:216, in Model._submit(self, runner_mode, dry_run)
#     209     resp = self._projects_api.create_model(
#     210         project_id=self.project.project_guid,
#     211         body=body,
#     212         dry_run=YES if dry_run else NO,
#     213         runner_mode=runner_mode.api_value,
#     214     )
#     215 except ApiException as ex:
# --> 216     self._handle_submit_error(ex)
#     218 self._data: dict = resp[f.DATA]
#     219 self.worker_key = resp[f.WORKER_KEY]
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:621, in Job._handle_submit_error(self, apix)
#     619     exc.body = apix.body
#     620     raise exc from apix
# --> 621 raise apix
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:209, in Model._submit(self, runner_mode, dry_run)
#     203     body = {
#     204         "config": body,
#     205         "provenance": provenance,
#     206     }
#     208 try:
# --> 209     resp = self._projects_api.create_model(
#     210         project_id=self.project.project_guid,
#     211         body=body,
#     212         dry_run=YES if dry_run else NO,
#     213         runner_mode=runner_mode.api_value,
#     214     )
#     215 except ApiException as ex:
#     216     self._handle_submit_error(ex)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:840, in Endpoint.__call__(self, *args, **kwargs)
#     829 def __call__(self, *args, **kwargs):
#     830     """This method is invoked when endpoints are called
#     831     Example:
#     832
#    (...)    838
#     839     """
# --> 840     return self.callable(self, *args, **kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api\projects_api.py:317, in ProjectsApi.__init__.<locals>.__create_model(self, project_id, body, **kwargs)
#     315 kwargs["project_id"] = project_id
#     316 kwargs["body"] = body
# --> 317 return self.call_with_http_info(**kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:912, in Endpoint.call_with_http_info(self, **kwargs)
#     907     header_list = self.api_client.select_header_content_type(
#     908         content_type_headers_list
#     909     )
#     910     params["header"]["Content-Type"] = header_list
# --> 912 return self.api_client.call_api(
#     913     self.settings["endpoint_path"],
#     914     self.settings["http_method"],
#     915     params["path"],
#     916     params["query"],
#     917     params["header"],
#     918     body=params["body"],
#     919     post_params=params["form"],
#     920     files=params["file"],
#     921     response_type=self.settings["response_type"],
#     922     auth_settings=self.settings["auth"],
#     923     async_req=kwargs["async_req"],
#     924     _check_type=kwargs["_check_return_type"],
#     925     _return_http_data_only=kwargs["_return_http_data_only"],
#     926     _preload_content=kwargs["_preload_content"],
#     927     _request_timeout=kwargs["_request_timeout"],
#     928     _host=_host,
#     929     collection_formats=params["collection_format"],
#     930 )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:424, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     370 """Makes the HTTP request (synchronous) and returns deserialized data.
#     371
#     372 To make an async_req request, set the async_req parameter.
#    (...)    421     then the method will return the response directly.
#     422 """
#     423 if not async_req:
# --> 424     return self.__call_api(
#     425         resource_path,
#     426         method,
#     427         path_params,
#     428         query_params,
#     429         header_params,
#     430         body,
#     431         post_params,
#     432         files,
#     433         response_type,
#     434         auth_settings,
#     435         _return_http_data_only,
#     436         collection_formats,
#     437         _preload_content,
#     438         _request_timeout,
#     439         _host,
#     440         _check_type,
#     441     )
#     443 return self.pool.apply_async(
#     444     self.__call_api,
#     445     (
#    (...)    462     ),
#     463 )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:211, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     209 except ApiException as e:
#     210     e.body = e.body.decode("utf-8")
# --> 211     raise e
#     213 self.last_response = response_data
#     215 return_data = response_data
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:199, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     195     url = _host + resource_path
#     197 try:
#     198     # perform request and return response
# --> 199     response_data = self.request(
#     200         method,
#     201         url,
#     202         query_params=query_params,
#     203         headers=header_params,
#     204         post_params=post_params,
#     205         body=body,
#     206         _preload_content=_preload_content,
#     207         _request_timeout=_request_timeout,
#     208     )
#     209 except ApiException as e:
#     210     e.body = e.body.decode("utf-8")
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:504, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     494     return self.rest_client.OPTIONS(
#     495         url,
#     496         query_params=query_params,
#    (...)    501         body=body,
#     502     )
#     503 elif method == "POST":
# --> 504     return self.rest_client.POST(
#     505         url,
#     506         query_params=query_params,
#     507         headers=headers,
#     508         post_params=post_params,
#     509         _preload_content=_preload_content,
#     510         _request_timeout=_request_timeout,
#     511         body=body,
#     512     )
#     513 elif method == "PUT":
#     514     return self.rest_client.PUT(
#     515         url,
#     516         query_params=query_params,
#    (...)    521         body=body,
#     522     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\rest.py:335, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     325 def POST(
#     326     self,
#     327     url,
#    (...)    333     _request_timeout=None,
#     334 ):
# --> 335     return self.request(
#     336         "POST",
#     337         url,
#     338         headers=headers,
#     339         query_params=query_params,
#     340         post_params=post_params,
#     341         _preload_content=_preload_content,
#     342         _request_timeout=_request_timeout,
#     343         body=body,
#     344     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\rest.py:247, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     244     if 500 <= r.status <= 599:
#     245         raise ServiceException(http_resp=r)
# --> 247     raise ApiException(http_resp=r)
#     249 return r
#
# ApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'date': 'Thu, 19 Jun 2025 04:56:32 GMT', 'server': 'uvicorn', 'content-type': 'application/json', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-length': '193'})
# HTTP response body: {"message": "Invalid Gretel Configuration", "context": {"validation_errors": [{"loc": ["models"], "msg": "Unknown model in the config 'tabular-gan'", "type": "value_error"}]}, "error_id": null}

# %%
----------------------------------------------------------------------------------------------------------------------------

# %%
import os
import pandas as pd
from gretel_client import configure_session
from gretel_client.projects import create_or_get_unique_project

# === Step 1: Set your Gretel API Key (replace with your actual key) ===
os.environ["GRETEL_API_KEY"] = "grtuda225cfaf130a33a1af5af2d2122564630efbbac068cc1fc02cdcf83d6f6c97d"

# === Step 2: Configure the Gretel session ===
configure_session(api_key=os.environ["GRETEL_API_KEY"], validate=True)

# === Step 3: Load your CSV data files for all main tables ===
customer_df = pd.read_csv("Customer.csv")
policy_df = pd.read_csv("Policy.csv")
claim_df = pd.read_csv("Claim.csv")
beneficiary_df = pd.read_csv("Beneficiary.csv")
coverage_df = pd.read_csv("Coverage.csv")
premium_df = pd.read_csv("Premium.csv")

# Lookup tables are only references, so you do NOT generate synthetic data for them.

# === Step 4: Create or get the Gretel project ===
project = create_or_get_unique_project(name="gretel-tabular-gan-synthetic")

# === Step 5: Define the model config dictionary for tabular GAN ===
model_config = {
    "models": [
        {
            "tabular-gan": {
                "epochs": 100
            }
        }
    ]
}
# === Step 6: Define function to train and generate synthetic data ===
def train_and_generate(table_name, df, num_rows):
    print(f"Starting training for {table_name} with {len(df)} original rows...")
    
    # Create the Gretel model object for this table
    model = project.create_model_obj(model_config=model_config, data_source=df)
    
    # Submit the training job and wait for it to complete
    model.submit()
    model.wait_for_completion()
    
    # Download synthetic data CSV artifact
    synthetic_path = model.get_artifact("synthetic_data")
    synthetic_df = pd.read_csv(synthetic_path)
    
    # Sample the desired number of rows (with replacement if requested size > generated rows)
    if num_rows > len(synthetic_df):
        sampled_df = synthetic_df.sample(n=num_rows, replace=True, random_state=42)
    else:
        sampled_df = synthetic_df.sample(n=num_rows, random_state=42)
    
    # Save the sampled synthetic data to CSV
    output_file = f"{table_name}_synthetic.csv"
    sampled_df.to_csv(output_file, index=False)
    
    print(f"Synthetic data for {table_name} saved to: {output_file}\n")

# === Step 7: Generate synthetic data for each main table with desired sample sizes ===
train_and_generate("Customer", customer_df, 1000)
train_and_generate("Policy", policy_df, 1500)
train_and_generate("Claim", claim_df, 800)
train_and_generate("Beneficiary", beneficiary_df, 600)
train_and_generate("Coverage", coverage_df, 700)
train_and_generate("Premium", premium_df, 900)

print("All synthetic datasets generated successfully.")
# Out:
# Logged in as nidyat@hexaware.com ✅
# Starting training for Customer with 5000 original rows...
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[27], line 67
#      64     print(f"Synthetic data for {table_name} saved to: {output_file}\n")
#      66 # === Step 7: Generate synthetic data for each main table with desired sample sizes ===
# ---> 67 train_and_generate("Customer", customer_df, 1000)
#      68 train_and_generate("Policy", policy_df, 1500)
#      69 train_and_generate("Claim", claim_df, 800)
#
# Cell In[27], line 47, in train_and_generate(table_name, df, num_rows)
#      44 model = project.create_model_obj(model_config=model_config, data_source=df)
#      46 # Submit the training job and wait for it to complete
# ---> 47 model.submit()
#      48 model.wait_for_completion()
#      50 # Download synthetic data CSV artifact
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:136, in Job.submit(self, runner_mode, dry_run)
#     131     raise ValueError(
#     132         f"Specified runner mode '{runner_mode.value}' is different from project runner mode '{self.project.runner_mode.value}'"
#     133     )
#     135 if runner_mode == RunnerMode.CLOUD:
# --> 136     return self.submit_cloud(dry_run)
#     137 elif runner_mode == RunnerMode.HYBRID:
#     138     return self.submit_hybrid(dry_run)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:168, in Job.submit_cloud(self, dry_run)
#     162 def submit_cloud(self, dry_run: bool = False) -> Job:
#     163     """Submit this Job to the Gretel Cloud API be scheduled for running in Gretel Cloud.
#     164
#     165     Returns:
#     166         The response from the Gretel API.
#     167     """
# --> 168     return self._submit_remote(
#     169         runner_mode=RunnerMode.CLOUD,
#     170         artifacts_handler=self.project.cloud_artifacts_handler,
#     171         dry_run=dry_run,
#     172     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:202, in Job._submit_remote(self, runner_mode, artifacts_handler, dry_run)
#     199 if not self.ref_data.is_empty:
#     200     self.upload_ref_data(_artifacts_handler=artifacts_handler)
# --> 202 return self._submit(runner_mode=runner_mode, dry_run=dry_run)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:216, in Model._submit(self, runner_mode, dry_run)
#     209     resp = self._projects_api.create_model(
#     210         project_id=self.project.project_guid,
#     211         body=body,
#     212         dry_run=YES if dry_run else NO,
#     213         runner_mode=runner_mode.api_value,
#     214     )
#     215 except ApiException as ex:
# --> 216     self._handle_submit_error(ex)
#     218 self._data: dict = resp[f.DATA]
#     219 self.worker_key = resp[f.WORKER_KEY]
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\jobs.py:621, in Job._handle_submit_error(self, apix)
#     619     exc.body = apix.body
#     620     raise exc from apix
# --> 621 raise apix
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\projects\models.py:209, in Model._submit(self, runner_mode, dry_run)
#     203     body = {
#     204         "config": body,
#     205         "provenance": provenance,
#     206     }
#     208 try:
# --> 209     resp = self._projects_api.create_model(
#     210         project_id=self.project.project_guid,
#     211         body=body,
#     212         dry_run=YES if dry_run else NO,
#     213         runner_mode=runner_mode.api_value,
#     214     )
#     215 except ApiException as ex:
#     216     self._handle_submit_error(ex)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:840, in Endpoint.__call__(self, *args, **kwargs)
#     829 def __call__(self, *args, **kwargs):
#     830     """This method is invoked when endpoints are called
#     831     Example:
#     832
#    (...)    838
#     839     """
# --> 840     return self.callable(self, *args, **kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api\projects_api.py:317, in ProjectsApi.__init__.<locals>.__create_model(self, project_id, body, **kwargs)
#     315 kwargs["project_id"] = project_id
#     316 kwargs["body"] = body
# --> 317 return self.call_with_http_info(**kwargs)
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:912, in Endpoint.call_with_http_info(self, **kwargs)
#     907     header_list = self.api_client.select_header_content_type(
#     908         content_type_headers_list
#     909     )
#     910     params["header"]["Content-Type"] = header_list
# --> 912 return self.api_client.call_api(
#     913     self.settings["endpoint_path"],
#     914     self.settings["http_method"],
#     915     params["path"],
#     916     params["query"],
#     917     params["header"],
#     918     body=params["body"],
#     919     post_params=params["form"],
#     920     files=params["file"],
#     921     response_type=self.settings["response_type"],
#     922     auth_settings=self.settings["auth"],
#     923     async_req=kwargs["async_req"],
#     924     _check_type=kwargs["_check_return_type"],
#     925     _return_http_data_only=kwargs["_return_http_data_only"],
#     926     _preload_content=kwargs["_preload_content"],
#     927     _request_timeout=kwargs["_request_timeout"],
#     928     _host=_host,
#     929     collection_formats=params["collection_format"],
#     930 )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:424, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     370 """Makes the HTTP request (synchronous) and returns deserialized data.
#     371
#     372 To make an async_req request, set the async_req parameter.
#    (...)    421     then the method will return the response directly.
#     422 """
#     423 if not async_req:
# --> 424     return self.__call_api(
#     425         resource_path,
#     426         method,
#     427         path_params,
#     428         query_params,
#     429         header_params,
#     430         body,
#     431         post_params,
#     432         files,
#     433         response_type,
#     434         auth_settings,
#     435         _return_http_data_only,
#     436         collection_formats,
#     437         _preload_content,
#     438         _request_timeout,
#     439         _host,
#     440         _check_type,
#     441     )
#     443 return self.pool.apply_async(
#     444     self.__call_api,
#     445     (
#    (...)    462     ),
#     463 )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:211, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     209 except ApiException as e:
#     210     e.body = e.body.decode("utf-8")
# --> 211     raise e
#     213 self.last_response = response_data
#     215 return_data = response_data
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:199, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     195     url = _host + resource_path
#     197 try:
#     198     # perform request and return response
# --> 199     response_data = self.request(
#     200         method,
#     201         url,
#     202         query_params=query_params,
#     203         headers=header_params,
#     204         post_params=post_params,
#     205         body=body,
#     206         _preload_content=_preload_content,
#     207         _request_timeout=_request_timeout,
#     208     )
#     209 except ApiException as e:
#     210     e.body = e.body.decode("utf-8")
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\api_client.py:504, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     494     return self.rest_client.OPTIONS(
#     495         url,
#     496         query_params=query_params,
#    (...)    501         body=body,
#     502     )
#     503 elif method == "POST":
# --> 504     return self.rest_client.POST(
#     505         url,
#     506         query_params=query_params,
#     507         headers=headers,
#     508         post_params=post_params,
#     509         _preload_content=_preload_content,
#     510         _request_timeout=_request_timeout,
#     511         body=body,
#     512     )
#     513 elif method == "PUT":
#     514     return self.rest_client.PUT(
#     515         url,
#     516         query_params=query_params,
#    (...)    521         body=body,
#     522     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\rest.py:335, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     325 def POST(
#     326     self,
#     327     url,
#    (...)    333     _request_timeout=None,
#     334 ):
# --> 335     return self.request(
#     336         "POST",
#     337         url,
#     338         headers=headers,
#     339         query_params=query_params,
#     340         post_params=post_params,
#     341         _preload_content=_preload_content,
#     342         _request_timeout=_request_timeout,
#     343         body=body,
#     344     )
#
# File ~\Downloads\myenv\Lib\site-packages\gretel_client\rest\rest.py:247, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     244     if 500 <= r.status <= 599:
#     245         raise ServiceException(http_resp=r)
# --> 247     raise ApiException(http_resp=r)
#     249 return r
#
# ApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'date': 'Thu, 19 Jun 2025 04:41:17 GMT', 'server': 'uvicorn', 'content-type': 'application/json', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-length': '193'})
# HTTP response body: {"message": "Invalid Gretel Configuration", "context": {"validation_errors": [{"loc": ["models"], "msg": "Unknown model in the config 'tabular-gan'", "type": "value_error"}]}, "error_id": null}

# %%
import pkg_resources
print(pkg_resources.get_distribution("gretel-client").version)
# Out:
# C:\Users\2000147874\AppData\Local\Temp\ipykernel_13068\2283907604.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 0.29.0

# %%
from gretel_client.models import get_available_models

print(get_available_models())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from gretel_client.models import get_available_models
#       3 print(get_available_models())
#
# ImportError: cannot import name 'get_available_models' from 'gretel_client.models' (C:\Users\2000147874\Downloads\myenv\Lib\site-packages\gretel_client\models\__init__.py)
